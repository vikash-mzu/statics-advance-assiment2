# %%
Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.
•	Probability Mass Function (PMF) is used for discrete random variables and gives the probability that a discrete random variable is exactly equal to a specific value.
o	Example: If we roll a die, the PMF for rolling a 4 would be P(X=4)=1/6P(X=4) = 1/6P(X=4)=1/6.
•	Probability Density Function (PDF) is used for continuous random variables. It gives the likelihood of the variable falling within a particular range of values, rather than at any specific point.
o	Example: If we model the heights of people in a population, we use a PDF to calculate the probability that someone's height falls between two values, say 160 cm and 170 cm.



Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why is CDF used?
•	Cumulative Density Function (CDF) describes the probability that a random variable takes a value less than or equal to a particular value. It is the cumulative sum of the probabilities for all values up to that point.
o	Example: For a normal distribution with a mean of 0 and a standard deviation of 1, the CDF at X=1X = 1X=1 represents the probability that a randomly selected value from the distribution will be less than or equal to 1.
•	Why is CDF used? CDFs are useful for understanding the probability of a value falling below a threshold and can help in comparing distributions or calculating probabilities for ranges of values.

                                    

Q3: What are some examples of situations where the normal distribution might be used as a model? Explain how the parameters of the normal distribution relate to the shape of the distribution.
•	Examples of Normal Distribution:
o	Heights of people.
o	Scores on a standardized test like SAT or GRE.
o	Measurement errors in experiments.
•	Parameters of Normal Distribution:
o	Mean (μ\muμ): Determines the center of the distribution.
o	Standard Deviation (σ\sigmaσ): Determines the spread or width of the distribution. A smaller σ\sigmaσ results in a narrower curve, while a larger σ\sigmaσ results in a wider curve.
The normal distribution is symmetric about the mean, and the spread is controlled by the standard deviation. Most of the data lies within 1 or 2 standard deviations from the mean.



Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution.
The Normal Distribution is important because it describes many natural phenomena and is the foundation of various statistical methods, including hypothesis testing and confidence intervals. Many real-world datasets follow a normal distribution, which makes it easier to apply statistical models and make predictions.
•	Real-life examples:
o	IQ scores.
o	Blood pressure measurements in a population.
o	Reaction times in cognitive experiments.



Q5: What is Bernoulli Distribution? Give an Example. What is the difference between Bernoulli Distribution and Binomial Distribution?
•	Bernoulli Distribution: A distribution representing two possible outcomes (success or failure) in a single trial, with probability ppp for success and 1−p1-p1−p for failure.
o	Example: Flipping a coin once (success = heads, failure = tails).
•	Difference between Bernoulli and Binomial Distributions:
o	Bernoulli Distribution: Represents a single trial.
o	Binomial Distribution: Represents the number of successes in nnn independent Bernoulli trials.

    
Q6: Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset is normally distributed, what is the probability that a randomly selected observation will be greater than 60? Use the appropriate formula and show your calculations.
•	To calculate the probability that a randomly selected observation will be greater than 60, we need to find the z-score and use the standard normal distribution.
Z=X−μσ=60−5010=1Z = \frac{X - \mu}{\sigma} = \frac{60 - 50}{10} = 1Z=σX−μ=1060−50=1
Using the standard normal distribution table, the probability of Z≤1Z \leq 1Z≤1 is approximately 0.8413. Therefore, the probability that a randomly selected observation is greater than 60 is:
P(X>60)=1−P(Z≤1)=1−0.8413=0.1587P(X > 60) = 1 - P(Z \leq 1) = 1 - 0.8413 = 0.1587P(X>60)=1−P(Z≤1)=1−0.8413=0.1587


Q7: Explain Uniform Distribution with an example.
•	Uniform Distribution is a type of distribution in which all outcomes are equally likely within a given range.
o	Example: Rolling a fair die has a uniform distribution, as each number (1 to 6) has an equal probability of occurring.


Q8: What is the z-score? State the importance of the z-score.
•	Z-score: A z-score represents how many standard deviations a data point is from the mean. It is used to standardize scores on different scales to a common scale (the standard normal distribution).
•	Importance: Z-scores allow comparison of data points from different distributions and help in identifying outliers.


Q9: What is Central Limit Theorem (CLT)? State the significance of the Central Limit Theorem.
•	Central Limit Theorem (CLT): States that the distribution of the sample means approaches a normal distribution as the sample size becomes large, regardless of the distribution of the population, provided the samples are independent and identically distributed.
•	Significance: CLT allows for the use of normal distribution in inferential statistics, even when the population distribution is not normal. It is the basis for many statistical procedures like hypothesis testing and confidence intervals.


Q10: State the assumptions of the Central Limit Theorem.
The assumptions of the Central Limit Theorem are:
1.	The samples must be independent.
2.	The samples should be identically distributed.
3.	The sample size should be sufficiently large (commonly n≥30n \geq 30n≥30).
